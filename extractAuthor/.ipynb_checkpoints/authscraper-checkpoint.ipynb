# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
authurl = "https://www.literotica.com/stories/memberpage.php?uid=1253141&page=submissions"

# %%
authurl = input ("Type literotica author story submissions url \nurl example - https://www.literotica.com/stories/memberpage.php?uid=1253141&page=submissions \nType URL:")
# Out:
# Type literotica author story submissions url
# url example - https://www.literotica.com/stories/memberpage.php?uid=1253141&page=submissions
# Type URL:https://www.literotica.com/stories/memberpage.php?uid=1253141&page=submissions

# %%
try:    
    authpagehtml = requests.get(authurl,headers={"User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"})
    print('auth found')
    authsoup = BeautifulSoup(authpagehtml.content, "lxml")
except:
    import traceback
    traceback.print_exc()
# Out:
# auth found

# %%
rootstories =[]
seriesstories = []
try:
    for pagedesc in authsoup.select('a[class*="contactheader"]'):
        author = pagedesc.text
except:
    import traceback
    traceback.print_exc()
    
try:
    for pagedesc in authsoup.select('tr[class*="root-story"]'):
        x = pagedesc.find_all("a")

        for page in x:
            lpstr = page.attrs['href']    
            if "/s/" in lpstr:
               rootstories.append(lpstr)
except:
    import traceback
    traceback.print_exc()
    
try:
    for pagedesc in authsoup.select('tr[class*="sl"]'):
        x = pagedesc.find_all("a")

        for page in x:
            lpstr = page.attrs['href']    
            if "/s/" in lpstr:
               seriesstories.append(lpstr)
except:
    import traceback
    traceback.print_exc()

# %%
allstories = rootstories + seriesstories
print( "stories to extract=> ",allstories)
# Out:
# stories to extract=>  ['https://www.literotica.com/s/foggy-night-in-india', 'https://www.literotica.com/s/indian-wife-is-a-diwali-night-treat-1', 'https://www.literotica.com/s/lonely-in-a-long-distance-marriage', 'https://www.literotica.com/s/my-unusual-marriage', 'https://www.literotica.com/s/the-things-you-do-for-family', 'https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-01', 'https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-02', 'https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-03', 'https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-04', 'https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-1', 'https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-2', 'https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-3', 'https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-4', 'https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-5', 'https://www.literotica.com/s/long-distance-is-a-bitch-ch-01', 'https://www.literotica.com/s/long-distance-is-a-bitch-ch-02', 'https://www.literotica.com/s/old-man-and-indian-wife-ch-01', 'https://www.literotica.com/s/old-man-and-indian-wife-ch-02', 'https://www.literotica.com/s/old-man-and-indian-wife-ch-03']

# %%
def extractStory(author,url):
    import os
    os.makedirs(author,exist_ok=True)
    try:    
        storyhtml = requests.get(url,headers={"User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"})
        print('story found')
        soup = BeautifulSoup(storyhtml.content, "lxml")
    except e:
        import traceback
        traceback.print_exc()


    fname= url.split("/s/")[-1] +".txt"
    fname

    lastpage=0
    try:
        for pagedesc in soup.select('div[class*="panel clearfix"]'):
            x = pagedesc.find_all("a")

            for page in x:
                lpstr = page.attrs['href']    
                if "page=" in lpstr:
                    lastpage = int(lpstr.split("page=")[1])
    #         print(lastpage)
    except:
        import traceback
        traceback.print_exc()

    lastpage

    pages_to_fetch = []
    pages_to_fetch.append(url)
    for p in range(2, lastpage+1):        
        if lastpage!=0:
            tempurl = url + "?page=" + str(p)
            pages_to_fetch.append(tempurl)

    pages_to_fetch

    def fetchpage(url):
        story = "ERROR!!!"
        try:       
            storyhtml = requests.get(url,headers={"User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"})
            print('fetching data from: ', url)
            soup = BeautifulSoup(storyhtml.content, "lxml")

            for storypart in soup.select('div[class*="panel article"]'):
                data = storypart.find_all('p')
                story = "\n\n".join([p1.text for p1 in data])
        except e:
            import traceback
            traceback.print_exc()

        return story


    import time
    fullstory = fname.split(".txt")[0]
    for page in pages_to_fetch:
        story = fetchpage(page)
    #     time.sleep(1)
        fullstory = fullstory + "\n\nSource:" + page + "\n\n" + story + "\n" 
    
    fullfilename = author +"/" + fname
    with open(fullfilename, 'w', encoding="utf-8") as f:
        f.write(fullstory)
        print("Story exported as :", fullfilename)

# %%
for url in allstories:
    try:
        print("----------------")
        print("Extracting story=> ", url)
        extractStory(author,url)
        print("----------------")
    except:
        import traceback
        traceback.print_exc()
# Out:
# ----------------
# Extracting story=>  https://www.literotica.com/s/foggy-night-in-india
# story found
# fetching data from:  https://www.literotica.com/s/foggy-night-in-india
# fetching data from:  https://www.literotica.com/s/foggy-night-in-india?page=2
# fetching data from:  https://www.literotica.com/s/foggy-night-in-india?page=3
# Story exported as : shiprat/foggy-night-in-india.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-wife-is-a-diwali-night-treat-1
# story found
# fetching data from:  https://www.literotica.com/s/indian-wife-is-a-diwali-night-treat-1
# fetching data from:  https://www.literotica.com/s/indian-wife-is-a-diwali-night-treat-1?page=2
# fetching data from:  https://www.literotica.com/s/indian-wife-is-a-diwali-night-treat-1?page=3
# fetching data from:  https://www.literotica.com/s/indian-wife-is-a-diwali-night-treat-1?page=4
# Story exported as : shiprat/indian-wife-is-a-diwali-night-treat-1.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/lonely-in-a-long-distance-marriage
# story found
# fetching data from:  https://www.literotica.com/s/lonely-in-a-long-distance-marriage
# fetching data from:  https://www.literotica.com/s/lonely-in-a-long-distance-marriage?page=2
# Story exported as : shiprat/lonely-in-a-long-distance-marriage.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/my-unusual-marriage
# story found
# fetching data from:  https://www.literotica.com/s/my-unusual-marriage
# fetching data from:  https://www.literotica.com/s/my-unusual-marriage?page=2
# Story exported as : shiprat/my-unusual-marriage.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/the-things-you-do-for-family
# story found
# fetching data from:  https://www.literotica.com/s/the-things-you-do-for-family
# fetching data from:  https://www.literotica.com/s/the-things-you-do-for-family?page=2
# fetching data from:  https://www.literotica.com/s/the-things-you-do-for-family?page=3
# Story exported as : shiprat/the-things-you-do-for-family.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-01
# story found
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-01
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-01?page=2
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-01?page=3
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-01?page=4
# Story exported as : shiprat/indian-social-worker-and-the-bully-ch-01.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-02
# story found
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-02
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-02?page=2
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-02?page=3
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-02?page=4
# Story exported as : shiprat/indian-social-worker-and-the-bully-ch-02.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-03
# story found
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-03
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-03?page=2
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-03?page=3
# Story exported as : shiprat/indian-social-worker-and-the-bully-ch-03.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-04
# story found
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-04
# fetching data from:  https://www.literotica.com/s/indian-social-worker-and-the-bully-ch-04?page=2
# Story exported as : shiprat/indian-social-worker-and-the-bully-ch-04.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-1
# story found
# fetching data from:  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-1
# fetching data from:  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-1?page=2
# Story exported as : shiprat/indian-wife-and-construction-guys-ch-05-1.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-2
# story found
# fetching data from:  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-2
# Story exported as : shiprat/indian-wife-and-construction-guys-ch-05-2.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-3
# story found
# fetching data from:  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-3
# Story exported as : shiprat/indian-wife-and-construction-guys-ch-05-3.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-4
# story found
# fetching data from:  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-4
# Story exported as : shiprat/indian-wife-and-construction-guys-ch-05-4.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-5
# story found
# fetching data from:  https://www.literotica.com/s/indian-wife-and-construction-guys-ch-05-5
# Story exported as : shiprat/indian-wife-and-construction-guys-ch-05-5.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/long-distance-is-a-bitch-ch-01
# story found
# fetching data from:  https://www.literotica.com/s/long-distance-is-a-bitch-ch-01
# fetching data from:  https://www.literotica.com/s/long-distance-is-a-bitch-ch-01?page=2
# fetching data from:  https://www.literotica.com/s/long-distance-is-a-bitch-ch-01?page=3
# Story exported as : shiprat/long-distance-is-a-bitch-ch-01.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/long-distance-is-a-bitch-ch-02
# story found
# fetching data from:  https://www.literotica.com/s/long-distance-is-a-bitch-ch-02
# fetching data from:  https://www.literotica.com/s/long-distance-is-a-bitch-ch-02?page=2
# Story exported as : shiprat/long-distance-is-a-bitch-ch-02.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/old-man-and-indian-wife-ch-01
# story found
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-01
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-01?page=2
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-01?page=3
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-01?page=4
# Story exported as : shiprat/old-man-and-indian-wife-ch-01.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/old-man-and-indian-wife-ch-02
# story found
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-02
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-02?page=2
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-02?page=3
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-02?page=4
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-02?page=5
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-02?page=6
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-02?page=7
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-02?page=8
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-02?page=9
# Story exported as : shiprat/old-man-and-indian-wife-ch-02.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/old-man-and-indian-wife-ch-03
# story found
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-03
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-03?page=2
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-03?page=3
# fetching data from:  https://www.literotica.com/s/old-man-and-indian-wife-ch-03?page=4
# Story exported as : shiprat/old-man-and-indian-wife-ch-03.txt
# ----------------
