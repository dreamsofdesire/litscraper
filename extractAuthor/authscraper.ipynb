# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
authurl = "https://www.literotica.com/stories/memberpage.php?uid=1253141&page=submissions"

# %%
authurl = input ("Type literotica author story submissions url \nurl example - https://www.literotica.com/stories/memberpage.php?uid=1253141&page=submissions \nType URL:")
# Out:
# Type literotica author story submissions url
# url example - https://www.literotica.com/stories/memberpage.php?uid=1253141&page=submissions
# Type URL:https://www.literotica.com/stories/memberpage.php?uid=1378788&page=submissions

# %%
try:    
    authpagehtml = requests.get(authurl,headers={"User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"})
    print('auth found')
    authsoup = BeautifulSoup(authpagehtml.content, "lxml")
except:
    import traceback
    traceback.print_exc()
# Out:
# auth found

# %%
rootstories =[]
seriesstories = []
try:
    for pagedesc in authsoup.select('a[class*="contactheader"]'):
        author = pagedesc.text
except:
    import traceback
    traceback.print_exc()
    
try:
    for pagedesc in authsoup.select('tr[class*="root-story"]'):
        x = pagedesc.find_all("a")

        for page in x:
            lpstr = page.attrs['href']    
            if "/s/" in lpstr:
               rootstories.append(lpstr)
except:
    import traceback
    traceback.print_exc()
    
try:
    for pagedesc in authsoup.select('tr[class*="sl"]'):
        x = pagedesc.find_all("a")

        for page in x:
            lpstr = page.attrs['href']    
            if "/s/" in lpstr:
               seriesstories.append(lpstr)
except:
    import traceback
    traceback.print_exc()

# %%
allstories = rootstories + seriesstories
print( "stories to extract=> ",allstories)
# Out:
# stories to extract=>  ['https://www.literotica.com/s/menage-a-trois-10', 'https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-01', 'https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-02', 'https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-03', 'https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-04', 'https://www.literotica.com/s/beautiful-housewife-banged', 'https://www.literotica.com/s/beautiful-housewife-banged-ch-02', 'https://www.literotica.com/s/blacked-in-goa-ch-01', 'https://www.literotica.com/s/blacked-in-goa-ch-02', 'https://www.literotica.com/s/blacked-in-goa-ch-03', 'https://www.literotica.com/s/blacked-in-goa-ch-04', 'https://www.literotica.com/s/blacked-in-goa-ch-05', 'https://www.literotica.com/s/carry-on-dentist-1', 'https://www.literotica.com/s/carry-on-dentist-ch-02', 'https://www.literotica.com/s/corridors-of-power-ch-01', 'https://www.literotica.com/s/corridors-of-power-ch-02', 'https://www.literotica.com/s/dirty-little-secret-ch-01-2', 'https://www.literotica.com/s/dirty-little-secret-ch-02-2', 'https://www.literotica.com/s/dirty-little-secret-ch-03-1', 'https://www.literotica.com/s/smitas-life-ch-01', 'https://www.literotica.com/s/smitas-life-ch-02', 'https://www.literotica.com/s/the-french-connection-ch-01-1', 'https://www.literotica.com/s/the-french-connection-ch-02-1', 'https://www.literotica.com/s/the-french-connection-ch-03-1', 'https://www.literotica.com/s/the-new-car-ch-01', 'https://www.literotica.com/s/the-new-car-ch-02', 'https://www.literotica.com/s/the-new-car-ch-03', 'https://www.literotica.com/s/the-new-car-ch-04']

# %%
def extractStory(author,url):
    import os
    os.makedirs(author,exist_ok=True)
    try:    
        storyhtml = requests.get(url,headers={"User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"})
        print('story found')
        soup = BeautifulSoup(storyhtml.content, "lxml")
    except e:
        import traceback
        traceback.print_exc()


    fname= url.split("/s/")[-1] +".txt"
    fname

    lastpage=0
    try:
        for pagedesc in soup.select('div[class*="panel clearfix"]'):
            x = pagedesc.find_all("a")

            for page in x:
                lpstr = page.attrs['href']    
                if "page=" in lpstr:
                    lastpage = int(lpstr.split("page=")[1])
    #         print(lastpage)
    except:
        import traceback
        traceback.print_exc()

    lastpage

    pages_to_fetch = []
    pages_to_fetch.append(url)
    for p in range(2, lastpage+1):        
        if lastpage!=0:
            tempurl = url + "?page=" + str(p)
            pages_to_fetch.append(tempurl)

    pages_to_fetch

    def fetchpage(url):
        story = "ERROR!!!"
        try:       
            storyhtml = requests.get(url,headers={"User-Agent" : "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36"})
            print('fetching data from: ', url)
            soup = BeautifulSoup(storyhtml.content, "lxml")

            for storypart in soup.select('div[class*="panel article"]'):
                data = storypart.find_all('p')
                story = "\n\n".join([p1.text for p1 in data])
        except e:
            import traceback
            traceback.print_exc()

        return story


    import time
    fullstory = fname.split(".txt")[0]
    for page in pages_to_fetch:
        story = fetchpage(page)
    #     time.sleep(1)
        fullstory = fullstory + "\n\nSource:" + page + "\n\n" + story + "\n" 
    
    fullfilename = author +"/" + fname
    with open(fullfilename, 'w', encoding="utf-8") as f:
        f.write(fullstory)
        print("Story exported as :", fullfilename)

# %%
for url in allstories:
    try:
        print("----------------")
        print("Extracting story=> ", url)
        extractStory(author,url)
        print("----------------")
    except:
        import traceback
        traceback.print_exc()
# Out:
# ----------------
# Extracting story=>  https://www.literotica.com/s/menage-a-trois-10
# story found
# fetching data from:  https://www.literotica.com/s/menage-a-trois-10
# fetching data from:  https://www.literotica.com/s/menage-a-trois-10?page=2
# Story exported as : bdrew86/menage-a-trois-10.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-01
# story found
# fetching data from:  https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-01
# fetching data from:  https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-01?page=2
# fetching data from:  https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-01?page=3
# Story exported as : bdrew86/a-remarkable-phase-of-my-life-ch-01.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-02
# story found
# fetching data from:  https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-02
# fetching data from:  https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-02?page=2
# fetching data from:  https://www.literotica.com/s/a-remarkable-phase-of-my-life-ch-02?page=3
# Extracting story=>  https://www.literotica.com/s/blacked-in-goa-ch-05
# story found
# fetching data from:  https://www.literotica.com/s/blacked-in-goa-ch-05
# fetching data from:  https://www.literotica.com/s/blacked-in-goa-ch-05?page=2
# fetching data from:  https://www.literotica.com/s/blacked-in-goa-ch-05?page=3
# fetching data from:  https://www.literotica.com/s/blacked-in-goa-ch-05?page=4
# fetching data from:  https://www.literotica.com/s/blacked-in-goa-ch-05?page=5
# Story exported as : bdrew86/blacked-in-goa-ch-05.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/carry-on-dentist-1
# story found
# fetching data from:  https://www.literotica.com/s/carry-on-dentist-1
# fetching data from:  https://www.literotica.com/s/carry-on-dentist-1?page=2
# Story exported as : bdrew86/carry-on-dentist-1.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/carry-on-dentist-ch-02
# story found
# fetching data from:  https://www.literotica.com/s/carry-on-dentist-ch-02
# fetching data from:  https://www.literotica.com/s/carry-on-dentist-ch-02?page=2
# fetching data from:  https://www.literotica.com/s/carry-on-dentist-ch-02?page=3
# Story exported as : bdrew86/carry-on-dentist-ch-02.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/corridors-of-power-ch-01
# story found
# fetching data from:  https://www.literotica.com/s/corridors-of-power-ch-01
# fetching data from:  https://www.literotica.com/s/corridors-of-power-ch-01?page=2
# fetching data from:  https://www.literotica.com/s/corridors-of-power-ch-01?page=3
# Story exported as : bdrew86/corridors-of-power-ch-01.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/corridors-of-power-ch-02
# story found
# fetching data from:  https://www.literotica.com/s/corridors-of-power-ch-02
# fetching data from:  https://www.literotica.com/s/corridors-of-power-ch-02?page=2
# Story exported as : bdrew86/corridors-of-power-ch-02.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/dirty-little-secret-ch-01-2
# story found
# fetching data from:  https://www.literotica.com/s/dirty-little-secret-ch-01-2
# fetching data from:  https://www.literotica.com/s/dirty-little-secret-ch-01-2?page=2
# Story exported as : bdrew86/dirty-little-secret-ch-01-2.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/dirty-little-secret-ch-02-2
# story found
# fetching data from:  https://www.literotica.com/s/dirty-little-secret-ch-02-2
# fetching data from:  https://www.literotica.com/s/dirty-little-secret-ch-02-2?page=2
# Story exported as : bdrew86/dirty-little-secret-ch-02-2.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/dirty-little-secret-ch-03-1
# story found
# fetching data from:  https://www.literotica.com/s/dirty-little-secret-ch-03-1
# fetching data from:  https://www.literotica.com/s/dirty-little-secret-ch-03-1?page=2
# fetching data from:  https://www.literotica.com/s/dirty-little-secret-ch-03-1?page=3
# Story exported as : bdrew86/dirty-little-secret-ch-03-1.txt
# ----------------
# ----------------
# Extracting story=>  https://www.literotica.com/s/smitas-life-ch-01
